# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#equations

def r_mid(r, r_2):
    r_mid= ((r_2 + r)/2)
    return r_mid

def lna(a):
    lna = np.log(a)
    return lna

def E(rm, Dv):
    E = (Dv)/rm
    return E

def rule4(errA,errB,A,B,a,b,Q):
    errQ= Q* np.sqrt(((a*errA)/A)**2 +((b*errB)/B)**2)
    return errQ

def rule3(errA,errB):
    errQ = np.sqrt(errA**2 + errB**2)
    return errQ

def err_ln(E, errE, lnE):
    err_ln= np.log(E+errE)-lnE
    return err_ln

# %%
# measured data

r1= 1.0
r2= 1.5
r3= 2.0
r4= 2.5
r5= 3.0
r6= 3.5
r7= 4.0
r8= 4.5
r9= 5.0
r10= 5.5
r11= 6.0
r12= 6.5
r13= 7.0

v1= 3.88
v2= 5.04
v3= 5.87
v4= 6.51
v5= 7.25
v6= 7.65
v7= 8.23
v8= 8.51
v9= 8.76
v10= 8.99
v11= 9.25
v12= 9.50
v13= 9.86

# %%
#calculated data

r_m1 = r_mid(r1, r2)
r_m2 = r_mid(r2, r3)
r_m3 = r_mid(r3, r4)
r_m4 = r_mid(r4, r5)
r_m5 = r_mid(r5, r6)
r_m6 = r_mid(r6, r7)
r_m7 = r_mid(r7, r8)
r_m8 = r_mid(r8, r9)
r_m9 = r_mid(r9, r10)
r_m10 = r_mid(r10, r11)
r_m11 = r_mid(r11, r12)
r_m12 = r_mid(r12, r13)

lnr1 = lna(r_m1)
lnr2 = lna(r_m2)
lnr3 = lna(r_m3)
lnr4 = lna(r_m4)
lnr5 = lna(r_m5)
lnr6 = lna(r_m6)
lnr7 = lna(r_m7)
lnr8 = lna(r_m8)
lnr9 = lna(r_m9)
lnr10 = lna(r_m10)
lnr11 = lna(r_m11)
lnr12 = lna(r_m12)

Dv1= v2-v1
Dv2= v3-v2
Dv3= v4-v3
Dv4= v5-v4
Dv5= v6-v5
Dv6= v7-v6
Dv7= v8-v7
Dv8= v9-v8
Dv9= v10-v9
Dv10= v11-v10
Dv11= v12-v11
Dv12= v13-v12

E1 = E(r_m1, Dv1)
E2 = E(r_m2, Dv2)
E3 = E(r_m3, Dv3)
E4 = E(r_m4, Dv4)
E5 = E(r_m5, Dv5)
E6 = E(r_m6, Dv6)
E7 = E(r_m7, Dv7)
E8 = E(r_m8, Dv8)
E9 = E(r_m9, Dv9)
E10 = E(r_m10, Dv10)
E11 = E(r_m11, Dv11)
E12 = E(r_m12, Dv12)

lnE1 = lna(E1)
lnE2 = lna(E2)
lnE3 = lna(E3)
lnE4 = lna(E4)
lnE5 = lna(E5)
lnE6 = lna(E6)
lnE7 = lna(E7)
lnE8 = lna(E8)
lnE9 = lna(E9)
lnE10 = lna(E10)
lnE11 = lna(E11)
lnE12 = lna(E12)

err_V= rule3(0.06,0.06)
err_rm= rule3(0.05,0.05)

errE1= rule4(err_V,err_rm,Dv1,r_m1,1,-1,E1)
errE2= rule4(err_V,err_rm,Dv2,r_m2,1,-1,E2)
errE3= rule4(err_V,err_rm,Dv3,r_m3,1,-1,E3)
errE4= rule4(err_V,err_rm,Dv4,r_m4,1,-1,E4)
errE5= rule4(err_V,err_rm,Dv5,r_m5,1,-1,E5)
errE6= rule4(err_V,err_rm,Dv6,r_m6,1,-1,E6)
errE7= rule4(err_V,err_rm,Dv7,r_m7,1,-1,E7)
errE8= rule4(err_V,err_rm,Dv8,r_m8,1,-1,E8)
errE9= rule4(err_V,err_rm,Dv9,r_m9,1,-1,E9)
errE10= rule4(err_V,err_rm,Dv10,r_m10,1,-1,E10)
errE11= rule4(err_V,err_rm,Dv11,r_m11,1,-1,E11)
errE12= rule4(err_V,err_rm,Dv12,r_m12,1,-1,E12)

errlnE1 = err_ln(E1, errE1, lnE1)
errlnE2 = err_ln(E2, errE2, lnE2)
errlnE3 = err_ln(E3, errE3, lnE3)
errlnE4 = err_ln(E4, errE4, lnE4)
errlnE5 = err_ln(E5, errE5, lnE5)
errlnE6 = err_ln(E6, errE6, lnE6)
errlnE7 = err_ln(E7, errE7, lnE7)
errlnE8 = err_ln(E8, errE8, lnE8)
errlnE9 = err_ln(E9, errE9, lnE9)
errlnE10 = err_ln(E10, errE10, lnE10)
errlnE11 = err_ln(E11, errE11, lnE11)
errlnE12 = err_ln(E12, errE12, lnE12)

print ("r_mid1=", r_m1)
print ("r_mid2=", r_m2)
print ("r_mid3=", r_m3)
print ("r_mid4=", r_m4)
print ("r_mid5=", r_m5)
print ("r_mid6=", r_m6)
print ("r_mid7=", r_m7)
print ("r_mid8=", r_m8)
print ("r_mid9=", r_m9)
print ("r_mid10=", r_m10)
print ("r_mid11=", r_m11)
print ("r_mid12=", r_m12)

print()

print ("d r_mid=", err_rm)

print ()

print ("change in V (2-1)=", Dv1)
print ("change in V (3-2)=", Dv2)
print ("change in V (4-3)=", Dv3)
print ("change in V (5-4)=", Dv4)
print ("change in V (6-5)=", Dv5)
print ("change in V (7-6)=", Dv6)
print ("change in V (8-9)=", Dv7)
print ("change in V (9-8)=", Dv8)
print ("change in V (10-9)=", Dv9)
print ("change in V (11-10)=", Dv10)
print ("change in V (12-11)=", Dv11)
print ("change in V (13-12)=", Dv12)

print()

print ("d change in V=", err_V)

print()

print ("ln(r_mid1)=", lnr1)
print ("ln(r_mid2)=", lnr2)
print ("ln(r_mid3)=", lnr3)
print ("ln(r_mid4)=", lnr4)
print ("ln(r_mid5)=", lnr5)
print ("ln(r_mid6)=", lnr6)
print ("ln(r_mid7)=", lnr7)
print ("ln(r_mid8)=", lnr8)
print ("ln(r_mid9)=", lnr9)
print ("ln(r_mid10)=", lnr10)
print ("ln(r_mid11)=", lnr11)
print ("ln(r_mid12)=", lnr12)

print()

print ("E1=", E1, "  d E1 =", errE1)
print ("E2=", E2, "  d E2 =", errE2)
print ("E3=", E3, "  d E3 =", errE3)
print ("E4=", E4, "  d E4 =", errE4)
print ("E5=", E5, "  d E5 =", errE5)
print ("E6=", E6, "  d E6 =", errE6)
print ("E7=", E7, "  d E7 =", errE7)
print ("E8=", E8, "  d E8 =", errE8)
print ("E9=", E9, "  d E9 =", errE9)
print ("E10=", E10, "  d E10 =", errE10)
print ("E11=", E11, "  d E11 =", errE11)
print ("E12=", E12, "  d E12 =", errE12)

print()

print ("ln(E1)=", lnE1, "  d ln(E1) =", errlnE1)
print ("ln(E2)=", lnE2, "  d ln(E2) =", errlnE2)
print ("ln(E3)=", lnE3, "  d ln(E3) =", errlnE3)
print ("ln(E4)=", lnE4, "  d ln(E4) =", errlnE4)
print ("ln(E5)=", lnE5, "  d ln(E5) =", errlnE5)
print ("ln(E6)=", lnE6, "  d ln(E6) =", errlnE6)
print ("ln(E7)=", lnE7, "  d ln(E7) =", errlnE7)
print ("ln(E8)=", lnE8, "  d ln(E8) =", errlnE8)
print ("ln(E9)=", lnE9, "  d ln(E9) =", errlnE9)
print ("ln(E10)=", lnE10, "  d ln(E10) =", errlnE10)
print ("ln(E11)=", lnE11, "  d ln(E11) =", errlnE11)
print ("ln(E12)=", lnE12, "  d ln(E12) =", errlnE12)

print()
# Out:
# r_mid1= 1.25
# r_mid2= 1.75
# r_mid3= 2.25
# r_mid4= 2.75
# r_mid5= 3.25
# r_mid6= 3.75
# r_mid7= 4.25
# r_mid8= 4.75
# r_mid9= 5.25
# r_mid10= 5.75
# r_mid11= 6.25
# r_mid12= 6.75
#
# d r_mid= 0.07071067811865477
#
# change in V (2-1)= 1.1600000000000001
# change in V (3-2)= 0.8300000000000001
# change in V (4-3)= 0.6399999999999997
# change in V (5-4)= 0.7400000000000002
# change in V (6-5)= 0.40000000000000036
# change in V (7-6)= 0.5800000000000001
# change in V (8-9)= 0.27999999999999936
# change in V (9-8)= 0.25
# change in V (10-9)= 0.23000000000000043
# change in V (11-10)= 0.2599999999999998
# change in V (12-11)= 0.25
# change in V (13-12)= 0.35999999999999943
#
# d change in V= 0.08485281374238571
#
# ln(r_mid1)= 0.22314355131420976
# ln(r_mid2)= 0.5596157879354227
# ln(r_mid3)= 0.8109302162163288
# ln(r_mid4)= 1.0116009116784799
# ln(r_mid5)= 1.1786549963416462
# ln(r_mid6)= 1.3217558399823195
# ln(r_mid7)= 1.4469189829363254
# ln(r_mid8)= 1.55814461804655
# ...

# %%
#graph stuff

xvariable_lnr = np.array([lnr12, lnr11, lnr10, lnr9, lnr8, lnr7, lnr6, lnr5, lnr4, lnr3, lnr2, lnr1])
yvariable_lnE = np.array([lnE12, lnE11, lnE10, lnE9, lnE8, lnE7, lnE6, lnE5, lnE4, lnE3, lnE2, lnE1]) 

err_yvariable_lnE = np.array([errlnE12, errlnE11, errlnE10, errlnE9, errlnE8, errlnE8, errlnE6, errlnE5,
                              errlnE4, errlnE3, errlnE2, errlnE1])

x = xvariable_lnr
y = yvariable_lnE
dy = err_yvariable_lnE


b,m=np.polynomial.polynomial.polyfit(x,y,1,w=dy)

fit = b+m*x

def Delta(x, dy):
    D = (sum(1/dy**2))*(sum(x**2/dy**2))-(sum(x/dy**2))**2
    return D
 
D=Delta(x, dy)
 
dm = np.sqrt(1/D*sum(1/dy**2)) 
db = np.sqrt(1/D*sum(x**2/dy**2)) 

def LLSFD2(x,y,dy):
    N = sum(((y-b-m*x)/dy)**2)
    return N
                      
N = LLSFD2(x,y,dy)


plt.figure(figsize=(15,10))
 
plt.plot(x, fit, color='pink', linestyle='--')
plt.scatter(x, y, color='blue', marker='o', facecolor='none')

plt.xlabel('ln(r/r) ln(cm)')
plt.ylabel('ln(E) ln(V/cm)')
plt.title('The Natural Log of the Radius Versus the Natural Log of the Electric Potential')
 
plt.errorbar(x, y, yerr=dy, xerr=None, fmt="none")
 
plt.annotate('n (no units) = {value:.{digits}E}'.format(value=m, digits=2),
             (0.05, 0.9), xycoords='axes fraction')
 
plt.annotate('Error in n (no units) = {value:.{digits}E}'.format(value=dm, digits=1),
             (0.05, 0.85), xycoords='axes fraction')
 
plt.annotate('Goodness of fit = {value:.{digits}E}'.format(value=N, digits=2),
             (0.05, 0.80), xycoords='axes fraction')

plt.show()
